# %%
# %matplotlib inline
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(sys.version)
print("Pandas:", pd.version.version)
# Out:
# 3.4.1 |Anaconda 2.0.1 (64-bit)| (default, Jun 11 2014, 17:27:11) [MSC v.1600 64 bit (AMD64)]
# Pandas: 0.14.0

# %%
df= pd.read_csv("date_fixed_data_time_added.csv", parse_dates=['Date'])

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Miles                  float64
# Time                    object
# Seconds                float64
# Minutes                float64
# Min_per_mile           float64
# dtype: object

# %%
df.head()
# Out:
#         Date  Miles Time  Seconds  Minutes  Min_per_mile
# 0 2014-08-01    0.0  NaN      NaN      NaN           NaN
# 1 2014-08-02    1.7  NaN      NaN      NaN           NaN
# 2 2014-08-03    1.4  NaN      NaN      NaN           NaN
# 3 2014-08-04    2.1  NaN      NaN      NaN           NaN
# 4 2014-08-05    0.0  NaN      NaN      NaN           NaN

# %%
df.describe()
# Out:
#             Miles       Seconds     Minutes  Min_per_mile
# count  168.000000     52.000000   52.000000     52.000000
# mean     1.512738   1901.788462   31.696474      7.725297
# std      2.966583   2560.424171   42.673736      0.954475
# min      0.000000    376.000000    6.266667      6.000000
# 25%      0.000000    583.750000    9.729167      7.020479
# 50%      0.000000   1343.500000   22.391667      7.533333
# 75%      2.002500   1743.250000   29.054167      8.480023
# max     26.200000  15643.000000  260.716667     10.000000

# %%
df.Minutes.max()
# Out:
# 260.71666666666664

# %%
df.Miles.max()
# Out:
# 26.199999999999999

# %%
df.Miles.min()
# Out:
# 0.0

# %%
df.Minutes.min()
# Out:
# 6.2666666666666675

# %%
df.min()
# Out:
# Date            2014-08-01 00:00:00
# Miles                             0
# Time                            NaN
# Seconds                         376
# Minutes                    6.266667
# Min_per_mile                      6
# dtype: object

# %%
df.Miles[df.Miles>0].min()
# Out:
# 0.65000000000000002

# %%
df.Miles[df.Miles >0].value_counts()
# Out:
# 1.37     14
# 3.05     11
# 1.50      7
# 1.34      3
# 5.30      2
# 3.00      2
# 0.65      2
# 2.50      2
# 0.90      2
# 14.80     2
# 3.10      2
# 2.00      2
# 5.63      2
# 3.40      1
# 4.03      1
# 5.00      1
# 2.38      1
# 4.08      1
# 1.40      1
# 2.10      1
# 3.15      1
# 12.00     1
# 5.20      1
# 1.42      1
# 4.63      1
# 1.00      1
# 2.30      1
# 26.20     1
# 1.87      1
# 2.21      1
# 6.50      1
# 1.67      1
# 3.36      1
# 2.35      1
# 4.00      1
# 2.93      1
# 1.26      1
# 1.78      1
# 1.20      1
# 2.01      1
# 1.70      1
# dtype: int64

# %%
df.Miles[df.Miles >0].value_counts().index[0]
# Out:
# 1.3700000000000001

# %%
df.Miles.cumsum().plot()

# %%
(df.Minutes.fillna(0).cumsum()).plot()

# %%
df.Date[0].strftime("%A")
# Out:
# 'Friday'

# %%
df.Date.map(lambda x: x.strftime("%A"))
# Out:
# 0        Friday
# 1      Saturday
# 2        Sunday
# 3        Monday
# 4       Tuesday
# 5     Wednesday
# 6      Thursday
# 7        Friday
# 8      Saturday
# 9        Sunday
# 10       Monday
# 11      Tuesday
# 12    Wednesday
# 13     Thursday
# 14     Thursday
# ...
# 153       Friday
# 154     Saturday
# 155       Sunday
# 156       Monday
# 157      Tuesday
# 158    Wednesday
# 159     Thursday
# 160       Friday
# 161     Saturday
# 162       Sunday
# 163       Monday
# 164      Tuesday
# 165    Wednesday
# 166     Thursday
# 167       Friday
# Name: Date, Length: 168, dtype: object

# %%
df['Day_of_the_week']= df.Date.map(lambda x: x.strftime("%A"))

# %%
df.head(10)
# Out:
#         Date  Miles     Time  Seconds    Minutes  Min_per_mile Day_of_the_week
# 0 2014-08-01   0.00      NaN      NaN        NaN           NaN          Friday
# 1 2014-08-02   1.70      NaN      NaN        NaN           NaN        Saturday
# 2 2014-08-03   1.40      NaN      NaN        NaN           NaN          Sunday
# 3 2014-08-04   2.10      NaN      NaN        NaN           NaN          Monday
# 4 2014-08-05   0.00      NaN      NaN        NaN           NaN         Tuesday
# 5 2014-08-06   2.38      NaN      NaN        NaN           NaN       Wednesday
# 6 2014-08-07   2.30      NaN      NaN        NaN           NaN        Thursday
# 7 2014-08-08   3.40      NaN      NaN        NaN           NaN          Friday
# 8 2014-08-09   2.50      NaN      NaN        NaN           NaN        Saturday
# 9 2014-08-10   3.36  0:28:37     1717  28.616667      8.516865          Sunday

# %%
df[df.Miles > 0].Day_of_the_week.value_counts().plot(kind='bar')

# %%
df[df.Miles > 0]
# Out:
#           Date  Miles     Time  Seconds     Minutes  Min_per_mile  \
# 1   2014-08-02   1.70      NaN      NaN         NaN           NaN
# 2   2014-08-03   1.40      NaN      NaN         NaN           NaN
# 3   2014-08-04   2.10      NaN      NaN         NaN           NaN
# 5   2014-08-06   2.38      NaN      NaN         NaN           NaN
# 6   2014-08-07   2.30      NaN      NaN         NaN           NaN
# 7   2014-08-08   3.40      NaN      NaN         NaN           NaN
# 8   2014-08-09   2.50      NaN      NaN         NaN           NaN
# 9   2014-08-10   3.36  0:28:37     1717   28.616667      8.516865
# 10  2014-08-11   1.67  0:13:07      787   13.116667      7.854291
# 11  2014-08-12   1.42  0:10:35      635   10.583333      7.453052
# 12  2014-08-13   2.35  0:17:25     1045   17.416667      7.411348
# 13  2014-08-14   0.90  0:06:16      376    6.266667      6.962963
# 14  2014-08-14   0.90  0:06:16      376    6.266667      6.962963
# ...

# %%
df.head()
# Out:
#         Date  Miles Time  Seconds  Minutes  Min_per_mile Day_of_the_week
# 0 2014-08-01    0.0  NaN      NaN      NaN           NaN          Friday
# 1 2014-08-02    1.7  NaN      NaN      NaN           NaN        Saturday
# 2 2014-08-03    1.4  NaN      NaN      NaN           NaN          Sunday
# 3 2014-08-04    2.1  NaN      NaN      NaN           NaN          Monday
# 4 2014-08-05    0.0  NaN      NaN      NaN           NaN         Tuesday

# %%
#del(df['Day of the week'])

# %%
df.head()
# Out:
#         Date  Miles Time  Seconds  Minutes  Min_per_mile Day_of_the_week
# 0 2014-08-01    0.0  NaN      NaN      NaN           NaN          Friday
# 1 2014-08-02    1.7  NaN      NaN      NaN           NaN        Saturday
# 2 2014-08-03    1.4  NaN      NaN      NaN           NaN          Sunday
# 3 2014-08-04    2.1  NaN      NaN      NaN           NaN          Monday
# 4 2014-08-05    0.0  NaN      NaN      NaN           NaN         Tuesday

# %%
df.drop('Time', axis=1)
# Out:
#           Date  Miles  Seconds     Minutes  Min_per_mile Day_of_the_week
# 0   2014-08-01   0.00      NaN         NaN           NaN          Friday
# 1   2014-08-02   1.70      NaN         NaN           NaN        Saturday
# 2   2014-08-03   1.40      NaN         NaN           NaN          Sunday
# 3   2014-08-04   2.10      NaN         NaN           NaN          Monday
# 4   2014-08-05   0.00      NaN         NaN           NaN         Tuesday
# 5   2014-08-06   2.38      NaN         NaN           NaN       Wednesday
# 6   2014-08-07   2.30      NaN         NaN           NaN        Thursday
# 7   2014-08-08   3.40      NaN         NaN           NaN          Friday
# 8   2014-08-09   2.50      NaN         NaN           NaN        Saturday
# 9   2014-08-10   3.36     1717   28.616667      8.516865          Sunday
# 10  2014-08-11   1.67      787   13.116667      7.854291          Monday
# 11  2014-08-12   1.42      635   10.583333      7.453052         Tuesday
# ...

# %%
df.drop('Seconds', axis=1)
# Out:
#           Date  Miles     Time     Minutes  Min_per_mile Day_of_the_week
# 0   2014-08-01   0.00      NaN         NaN           NaN          Friday
# 1   2014-08-02   1.70      NaN         NaN           NaN        Saturday
# 2   2014-08-03   1.40      NaN         NaN           NaN          Sunday
# 3   2014-08-04   2.10      NaN         NaN           NaN          Monday
# 4   2014-08-05   0.00      NaN         NaN           NaN         Tuesday
# 5   2014-08-06   2.38      NaN         NaN           NaN       Wednesday
# 6   2014-08-07   2.30      NaN         NaN           NaN        Thursday
# 7   2014-08-08   3.40      NaN         NaN           NaN          Friday
# 8   2014-08-09   2.50      NaN         NaN           NaN        Saturday
# 9   2014-08-10   3.36  0:28:37   28.616667      8.516865          Sunday
# 10  2014-08-11   1.67  0:13:07   13.116667      7.854291          Monday
# 11  2014-08-12   1.42  0:10:35   10.583333      7.453052         Tuesday
# ...

# %%
tempdf= pd.DataFrame(np.arange(4).reshape(2,2))

# %%
tempdf
# Out:
#    0  1
# 0  0  1
# 1  2  3

# %%
tempdf.drop(1,axis=0)
# Out:
#    0  1
# 0  0  1

# %%
tempdf.append(pd.Series([4,5]), ignore_index=True)
# Out:
#    0  1
# 0  0  1
# 1  2  3
# 2  4  5

# %%
df.head()
# Out:
#         Date  Miles Time  Seconds  Minutes  Min_per_mile Day_of_the_week
# 0 2014-08-01    0.0  NaN      NaN      NaN           NaN          Friday
# 1 2014-08-02    1.7  NaN      NaN      NaN           NaN        Saturday
# 2 2014-08-03    1.4  NaN      NaN      NaN           NaN          Sunday
# 3 2014-08-04    2.1  NaN      NaN      NaN           NaN          Monday
# 4 2014-08-05    0.0  NaN      NaN      NaN           NaN         Tuesday

# %%
df.pop('Seconds')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9     1717
# 10     787
# 11     635
# 12    1045
# 13     376
# 14     376
# ...
# 153     1575
# 154     8100
# 155      NaN
# 156     1680
# 157     3110
# 158     1508
# 159     8400
# 160      NaN
# 161      NaN
# 162      NaN
# 163      NaN
# 164     1330
# 165      NaN
# 166    15643
# 167      NaN
# Name: Seconds, Length: 168, dtype: float64

# %%
df
# Out:
#           Date  Miles     Time     Minutes  Min_per_mile Day_of_the_week
# 0   2014-08-01   0.00      NaN         NaN           NaN          Friday
# 1   2014-08-02   1.70      NaN         NaN           NaN        Saturday
# 2   2014-08-03   1.40      NaN         NaN           NaN          Sunday
# 3   2014-08-04   2.10      NaN         NaN           NaN          Monday
# 4   2014-08-05   0.00      NaN         NaN           NaN         Tuesday
# 5   2014-08-06   2.38      NaN         NaN           NaN       Wednesday
# 6   2014-08-07   2.30      NaN         NaN           NaN        Thursday
# 7   2014-08-08   3.40      NaN         NaN           NaN          Friday
# 8   2014-08-09   2.50      NaN         NaN           NaN        Saturday
# 9   2014-08-10   3.36  0:28:37   28.616667      8.516865          Sunday
# 10  2014-08-11   1.67  0:13:07   13.116667      7.854291          Monday
# 11  2014-08-12   1.42  0:10:35   10.583333      7.453052         Tuesday
# ...

# %%
ndf= df[df.Miles !=0]

# %%
ndf.groupby('Day_of_the_week')

# %%
for dow in df.Day_of_the_week.unique():
    print(dow)
# Out:
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday

# %%
dows= ndf.groupby('Day_of_the_week')

# %%
dows.size()
# Out:
# Day_of_the_week
# Friday             15
# Monday             14
# Saturday           14
# Sunday             11
# Thursday            8
# Tuesday            11
# Wednesday           8
# dtype: int64

# %%
dows.count()
# Out:
#                  Date  Miles  Time  Minutes  Min_per_mile
# Day_of_the_week
# Friday             15     15     8        8             8
# Monday             14     14    10       10            10
# Saturday           14     14     6        6             6
# Sunday             11     11     8        8             8
# Thursday            8      8     5        5             5
# Tuesday            11     11     8        8             8
# Wednesday           8      8     7        7             7

# %%
dows.mean()
# Out:
#                     Miles    Minutes  Min_per_mile
# Day_of_the_week
# Friday           2.786000  24.308333      7.747657
# Monday           2.607143  22.243333      7.463291
# Saturday         3.246429  46.708333      8.184961
# Sunday           2.422727  19.762500      7.463840
# Thursday         6.315000  84.530000      8.039543
# Tuesday          2.428182  21.770833      7.659706
# Wednesday        3.315000  28.021429      7.829348

# %%
dows.sum()
# Out:
#                  Miles     Minutes  Min_per_mile
# Day_of_the_week
# Friday           41.79  194.466667     61.981259
# Monday           36.50  222.433333     74.632908
# Saturday         45.45  280.250000     49.109769
# Sunday           26.65  158.100000     59.710723
# Thursday         50.52  422.650000     40.197717
# Tuesday          26.71  174.166667     61.277645
# Wednesday        26.52  196.150000     54.805434

# %%
dows.describe()
# Out:
#                            Miles  Min_per_mile     Minutes
# Day_of_the_week
# Friday          count  15.000000      8.000000    8.000000
#                 mean    2.786000      7.747657   24.308333
#                 std     1.510718      0.844590   15.376198
#                 min     1.200000      6.630170    9.083333
#                 25%     1.370000      7.025547    9.625000
#                 50%     3.000000      7.803279   23.800000
#                 75%     3.250000      8.523306   30.550000
#                 max     5.630000      8.718176   49.083333
# Monday          count  14.000000     10.000000   10.000000
#                 mean    2.607143      7.463291   22.243333
#                 std     1.688538      1.037698   16.318699
#                 min     0.650000      6.000000    8.600000
#                 25%     1.402500      6.677835    9.637500
#                 50%     1.885000      7.520672   17.516667
#                 75%     3.087500      7.815719   26.795833
# ...

# %%
dows.std()
# Out:
#                     Miles     Minutes  Min_per_mile
# Day_of_the_week
# Friday           1.510718   15.376198      0.844590
# Monday           1.688538   16.318699      1.037698
# Saturday         3.592504   45.119311      0.926076
# Sunday           1.000241    8.282836      0.578829
# Thursday         9.300811  114.032318      1.531027
# Tuesday          1.321990   13.777549      0.830158
# Wednesday        3.562291   32.039394      1.142713

# %%
for name, group in dows: 
    print(name)
    print(group.head())
    break
# Out:
# Friday
#          Date  Miles     Time    Minutes  Min_per_mile Day_of_the_week
# 7  2014-08-08   3.40      NaN        NaN           NaN          Friday
# 15 2014-08-15   1.78      NaN        NaN           NaN          Friday
# 23 2014-08-22   1.37  0:09:05   9.083333      6.630170          Friday
# 31 2014-08-29   5.00  0:43:27  43.450000      8.690000          Friday
# 38 2014-09-05   3.05  0:23:50  23.833333      7.814208          Friday

# %%
dows.get_group('Friday')
# Out:
#           Date  Miles  Min_per_mile    Minutes     Time
# 7   2014-08-08   3.40           NaN        NaN      NaN
# 15  2014-08-15   1.78           NaN        NaN      NaN
# 23  2014-08-22   1.37      6.630170   9.083333  0:09:05
# 31  2014-08-29   5.00      8.690000  43.450000  0:43:27
# 38  2014-09-05   3.05      7.814208  23.833333  0:23:50
# 45  2014-09-12   3.05      7.792350  23.766667  0:23:46
# 52  2014-09-19   1.37      7.116788   9.750000  0:09:45
# 99  2014-10-31   2.01           NaN        NaN      NaN
# 106 2014-11-07   5.63      8.718176  49.083333  0:49:05
# 107 2014-11-07   1.26           NaN        NaN      NaN
# 108 2014-11-07   1.20           NaN        NaN      NaN
# 131 2014-11-28   3.00           NaN        NaN      NaN
# 145 2014-12-12   1.37      6.751825   9.250000  0:09:15
# 153 2014-12-19   3.10      8.467742  26.250000  0:26:15
# 160 2014-12-26   5.20           NaN        NaN      NaN

# %%
dows.agg(lambda x: len(x))['Miles']
# Out:
# Day_of_the_week
# Friday             15
# Monday             14
# Saturday           14
# Sunday             11
# Thursday            8
# Tuesday            11
# Wednesday           8
# Name: Miles, dtype: float64

# %%
# ?dows.agg

# %%
ndf['Count']= 1

# %%
ndf.head()
# Out:
#         Date  Miles Time  Minutes  Min_per_mile Day_of_the_week  Count
# 1 2014-08-02   1.70  NaN      NaN           NaN        Saturday      1
# 2 2014-08-03   1.40  NaN      NaN           NaN          Sunday      1
# 3 2014-08-04   2.10  NaN      NaN           NaN          Monday      1
# 5 2014-08-06   2.38  NaN      NaN           NaN       Wednesday      1
# 6 2014-08-07   2.30  NaN      NaN           NaN        Thursday      1

# %%
ndf.groupby('Day_of_the_week').sum()
# Out:
#                  Miles     Minutes  Min_per_mile  Count
# Day_of_the_week
# Friday           41.79  194.466667     61.981259     15
# Monday           36.50  222.433333     74.632908     14
# Saturday         45.45  280.250000     49.109769     14
# Sunday           26.65  158.100000     59.710723     11
# Thursday         50.52  422.650000     40.197717      8
# Tuesday          26.71  174.166667     61.277645     11
# Wednesday        26.52  196.150000     54.805434      8
